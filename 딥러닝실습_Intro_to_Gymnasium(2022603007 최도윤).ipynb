# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_01_ai_gym.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# **Module 12: Reinforcement Learning**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).
# * Modified by uramoon@kw.ac.kr

# %% [markdown]
# # Module 12 Video Material
#
# * **Part 12.1: Introduction to the OpenAI Gym** [[Video]](https://www.youtube.com/watch?v=_KbUxgyisjM&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_01_ai_gym.ipynb)
# * Part 12.2: Introduction to Q-Learning [[Video]](https://www.youtube.com/watch?v=A3sYFcJY3lA&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_02_qlearningreinforcement.ipynb)
# * Part 12.3: Keras Q-Learning in the OpenAI Gym [[Video]](https://www.youtube.com/watch?v=qy1SJmsRhvM&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_03_keras_reinforce.ipynb)
# * Part 12.4: Atari Games with Keras Neural Networks [[Video]](https://www.youtube.com/watch?v=co0SwPWoZh0&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_04_atari.ipynb)
# * Part 12.5: Application of Reinforcement Learning [[Video]](https://www.youtube.com/watch?v=1jQPP3RfwMI&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_05_apply_rl.ipynb)

# %% [markdown]
# # Part 12.1: Introduction to the Gymnasium
#
# Gymnasium은 강화학습을 위해 만든 API입니다.
#
# ## Gymnasium Leaderboard
#
# * [Gymnasium Leaderboard](https://github.com/openai/gym/wiki/Leaderboard)
#
# You must provide a write-up with sufficient instructions to reproduce your result if you submit a score. A video of your results is suggested but not required.
#
# ## Looking at Gymnasium Environments
#
# Gymnasium은 강화학습을 수행할 수 있는 환경을 제공합니다.
# The centerpiece of Gym is the environment, which defines the "game" in which your reinforcement algorithm will compete. An environment does not need to be a game; however, it describes the following game-like features:
# * **action space**: 매 스텝에서 취할 수 있는 행동 목록 제공
# * **observation space**: 현재 관측 가능한 상태 제공
#
# Before we begin to look at Gym, it is essential to understand some of the terminology used by this library.
#
# * **Agent** - 매 스텝 행동을 취하는 기계 학습 프로그램, 행동에 따라 다음 상태가 달라집니다.
# * **Episode** - 연속된 스텝들의 모음. 에이전트가 실패하거나 미리 정해놓은 최대 스텝에 도달하면 에피소드는 종료합니다.
# * **Render** - Gymnasium은 frame단위로 에피소드에서 발생한 일들을 그릴 수 있습니다.
# * **Reward** - 에피소드가 끝날 때 행동에 따라 에이전트는 보상을 받을 수 있습니다.
# * **Non-deterministic** - 어떤 환경에서는 보상이 확률적으로 주어집니다. 예) 복권
#
# It is important to note that many gym environments specify that they are not non-deterministic even though they use random numbers to process actions. Based on the gym GitHub issue tracker, a non-deterministic property means a deterministic environment behaves randomly. Even when you give the environment a consistent seed value, this behavior is confirmed. The program can use the seed method of an environment to seed the random number generator for the environment.
#
# The Gym library allows us to query some of these attributes from environments. I created the following function to query gym environments.

# %%
# 현재 버전은 Colab에서 문제가 있어 구버전 설치
# !pip install gym==0.17.3
# !pip install pyglet==1.5.11
# Out:
# Collecting gym==0.17.3
#   Downloading gym-0.17.3.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gym==0.17.3) (1.13.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.10/dist-packages (from gym==0.17.3) (1.26.4)
# Collecting pyglet<=1.5.0,>=1.4.0 (from gym==0.17.3)
#   Downloading pyglet-1.5.0-py2.py3-none-any.whl.metadata (7.6 kB)
# Collecting cloudpickle<1.7.0,>=1.2.0 (from gym==0.17.3)
#   Downloading cloudpickle-1.6.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3) (1.0.0)
# Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Downloading pyglet-1.5.0-py2.py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 14.8 MB/s eta 0:00:00
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.17.3-py3-none-any.whl size=1654616 sha256=cd3a88921577a9a4d63a9738a5d9d8912d1cbcfe5bcf1adabaa962fc7bb1a864
#   Stored in directory: /root/.cache/pip/wheels/af/4b/74/fcfc8238472c34d7f96508a63c962ff3ac9485a9a4137afd4e
# Successfully built gym
# Installing collected packages: pyglet, cloudpickle, gym
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.1.0
#     Uninstalling cloudpickle-3.1.0:
#       Successfully uninstalled cloudpickle-3.1.0
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.29.0 requires cloudpickle>=2.0.0, but you have cloudpickle 1.6.0 which is incompatible.
# dask 2024.10.0 requires cloudpickle>=3.0.0, but you have cloudpickle 1.6.0 which is incompatible.
# Successfully installed cloudpickle-1.6.0 gym-0.17.3 pyglet-1.5.0
# Collecting pyglet==1.5.11
#   Downloading pyglet-1.5.11-py3-none-any.whl.metadata (7.6 kB)
# Downloading pyglet-1.5.11-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.6 MB/s eta 0:00:00
# Installing collected packages: pyglet
#   Attempting uninstall: pyglet
#     Found existing installation: pyglet 1.5.0
#     Uninstalling pyglet-1.5.0:
#       Successfully uninstalled pyglet-1.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gym 0.17.3 requires pyglet<=1.5.0,>=1.4.0, but you have pyglet 1.5.11 which is incompatible.
# Successfully installed pyglet-1.5.11

# %%
import gym

# name에 해당하는 환경의 정보를 출력해주는 함수
def query_environment(name):
    env = gym.make(name)
    spec = gym.spec(name)
    print(f"Action Space: {env.action_space}")
    print(f"Observation Space: {env.observation_space}")
    print(f"Max Episode Steps: {spec.max_episode_steps}")
    print(f"Nondeterministic: {spec.nondeterministic}")
    print(f"Reward Range: {env.reward_range}")
    print(f"Reward Threshold: {spec.reward_threshold}")

# %% [markdown]
# ## MountainCar 환경 살펴보기
# We will look at the **MountainCar-v0** environment, which challenges an underpowered car to escape the valley between two mountains.  The following code describes the Mountian Car environment.
#
# <img src='https://gymnasium.farama.org/_images/mountain_car.gif' width="360">

# %%
query_environment("MountainCar-v0")
# Out:
# Action Space: Discrete(3)
# Observation Space: Box(-1.2000000476837158, 0.6000000238418579, (2,), float32)
# Max Episode Steps: 200
# Nondeterministic: False
# Reward Range: (-inf, inf)
# Reward Threshold: -110.0

# %% [markdown]
# ### TODO: MountainCar 질문에 대한 답 작성
# Hint: https://gymnasium.farama.org/environments/classic_control/mountain_car/

# %%
# Q: MountainCar-v0에서는 매 스텝 어떤 행동을 취할 수 있을까요? 각 행동의 의미를 기재하세요.
# A: 0:왼쪽으로 가속 , 1:정지 , 2:오른쪽으로 가속

# Q: 관측할 수 있는 것은 실수 두 개인데 각 실수는 무엇을 의미할까요?
# A: 첫 번째 실수: 현재 위치 , 두 번째 실수: 현재 속도

# Q: 강화학습의 목표는 최대한 많은 리워드를 받는 것입니다.
# 이 환경에서는 골인 지점에 있지 않으면 매 스텝 -1의 리워드가 주어지는데 어떻게 행동해야 할까요?
# A: 양쪽 방향으로 번갈아 가속시킵니다.

# %% [markdown]
# ## CartPole 환경 살펴보기
# <img src="https://gymnasium.farama.org/_images/cart_pole.gif" width="360">

# %%
query_environment("CartPole-v1")
# Out:
# Action Space: Discrete(2)
# Observation Space: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)
# Max Episode Steps: 500
# Nondeterministic: False
# Reward Range: (-inf, inf)
# Reward Threshold: 475.0

# %% [markdown]
# ## TODO: CartPole 질문에 대한 답 작성
# Hint: https://gymnasium.farama.org/environments/classic_control/cart_pole/

# %%
# Q: CartPole-v1에서는 매 스텝 어떤 행동을 취할 수 있을까요? 각 행동의 의미를 기재하세요.
# A: 0:왼쪽으로 이동 , 1:오른쪽으로 이동

# Q: 관측할 수 있는 것은 실수 네 개인데 각 실수는 무엇을 의미할까요?
# A: 첫 번째 실수: 카트의 위치 , 두 번째 실수: 카트의 속도, 세 번째 실수: 막대의 각도 , 네 번째 실수: 막대의 가속도

# Q: Observation Space에 기재된 에피소드 종료 조건 세 가지는 무엇일까요?
# A: 첫 번째 종료조건: 막대의 각도가 +,-12도 이상인 경우 , 두 번째 종료조건: 카트의 위치가 레일을 벗어난 경우 , 세 번째 종료조건: 최대 스텝 수를 초과한 경우

# Q: 강화학습의 목표는 최대한 많은 리워드를 받는 것입니다.
# 이 환경에서는 매 스텝 +1의 리워드가 주어지는데 어떻게 행동해야 할까요?
# A: 막대가 기울어지는 방향으로 카트를 신속히 이동해야 합니다.

# %% [markdown]
# ## Atari ROM 파일 다운로드
#
# Note: If you see a warning above, you can safely ignore it; it is a relatively minor bug in OpenAI Gym.
#
# Atari games, like breakout, can use an observation space that is either equal to the size of the Atari screen (210x160) or even use the RAM of the Atari (128 bytes) to determine the state of the game.  Yes, that's bytes, not kilobytes!

# %%
# !wget http://www.atarimania.com/roms/Roms.rar
# !unrar x -o+ /content/Roms.rar >/dev/nul
# !pip install atari_py
# !python -m atari_py.import_roms /content/ROMS >/dev/nul
# Out:
# --2025-01-07 04:48:56--  http://www.atarimania.com/roms/Roms.rar
# Resolving www.atarimania.com (www.atarimania.com)... 212.83.163.6
# Connecting to www.atarimania.com (www.atarimania.com)|212.83.163.6|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.atarimania.com/roms/Roms.rar [following]
# --2025-01-07 04:48:57--  https://www.atarimania.com/roms/Roms.rar
# Connecting to www.atarimania.com (www.atarimania.com)|212.83.163.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19612325 (19M) [application/octet-stream]
# Saving to: ‘Roms.rar’
#
# Roms.rar            100%[===================>]  18.70M  8.49MB/s    in 2.2s
#
# 2025-01-07 04:48:59 (8.49 MB/s) - ‘Roms.rar’ saved [19612325/19612325]
#
# Collecting atari_py
#   Downloading atari-py-0.2.9.tar.gz (540 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.6/540.6 kB 12.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from atari_py) (1.26.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from atari_py) (1.17.0)
# Building wheels for collected packages: atari_py

# %% [markdown]
# ## 두 가지 버전의 벽돌깨기 (Breakout) 게임 환경
# <img src="https://gymnasium.farama.org/v0.26.3/_images/breakout.gif" width="160"><br>
# https://gymnasium.farama.org/environments/atari/breakout/

# %%
# 인간 플레이어와 동일하게 210 x 160, 3채널 컬러 이미지를 관측하는 환경 (각 픽셀값은 0 ~ 255)
query_environment("Breakout-v0")
# Out:
# Action Space: Discrete(4)
# Observation Space: Box(0, 255, (210, 160, 3), uint8)
# Max Episode Steps: 10000
# Nondeterministic: False
# Reward Range: (-inf, inf)
# Reward Threshold: None

# %%
# Atari 게임기의 128 bytes 메모리를 관측하는 환경 (각 바이트는 0 ~ 255)
query_environment("Breakout-ram-v0")
# Out:
# Action Space: Discrete(4)
# Observation Space: Box(0, 255, (128,), uint8)
# Max Episode Steps: 10000
# Nondeterministic: False
# Reward Range: (-inf, inf)
# Reward Threshold: None

# %% [markdown]
# ## Render OpenAI Gym Environments from CoLab
#
# 그려봅시다!
#
# It is possible to visualize the game your agent is playing, even on CoLab. This section provides information on generating a video in CoLab that shows you an episode of the game your agent is playing. I based this video process on suggestions found [here](https://colab.research.google.com/drive/1flu31ulJlgiRL1dnN2ir8wGh9p7Zij2t).
#
# Begin by installing **pyvirtualdisplay** and **python-opengl**.

# %%
# 이해할 필요 없습니다.
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python3-opengl ffmpeg > /dev/null 2>&1

# %% [markdown]
# Next, we install the needed requirements to display an Atari game.

# %%
# 이해할 필요 없습니다.
# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
#!pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# !pip install gym[atari] > /dev/null 2>&1

# %% [markdown]
# Next, we define the functions used to show the video by adding it to the CoLab notebook.

# %%
# 이해할 필요 없습니다.
import gym
from gym.wrappers import Monitor
import glob
import io
import base64
from IPython.display import HTML
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay

display = Display(visible=0, size=(1400, 900))
display.start()

"""
Utility functions to enable video recording of gym environment
and displaying it.
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
    mp4list = glob.glob('video/*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")

def wrap_env(env):
    env = Monitor(env, './video', force=True)
    return env

# %% [markdown]
# ### 아틀란티스 게임에서 랜덤 에이전트의 행동 그려보기
#
# 아틀란티스라는 게임은 플레이어가 매 스텝 다음의 행동을 취할 수 있습니다.
# 0. 아무것도 안함
# 1. 가운데 총 발사
# 2. 오른쪽 총 발사
# 3. 왼쪽 총 발사
#
# 매 번 랜덤한 행동을 취하는 에이전트의 플레이를 그려보겠습니다.

# %%
env = wrap_env(gym.make("Atlantis-v0"))
observation = env.reset()

while True:
    # 매 스텝 다음을 수행

    # 그리기
    env.render()

    # 액션 정하기
    action = env.action_space.sample()  # 랜덤하게 설정

    # 행동에 따른 새로운 관측, 리워드, 에피소드 종료 여부, 종료에 관한 정보를 반환
    observation, reward, done, info = env.step(action)

    if done:
        break

env.close()
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ## TODO: Kung Fu Master 랜덤 에이전트 만들기
# https://gymnasium.farama.org/environments/atari/kung_fu_master/<br>
# 매 스텝 무작위 액션을 취하는 에이전트를 만들어 플레이 장면을 그려보세요.

# %%
env = wrap_env(gym.make("KungFuMaster-v4"))

#TODO
observation = env.reset()

while True:
    # 매 스텝 다음을 수행

    # 그리기
    env.render()

    # 액션 정하기
    action = env.action_space.sample()  # 랜덤하게 설정

    # 행동에 따른 새로운 관측, 리워드, 에피소드 종료 여부, 종료에 관한 정보를 반환
    observation, reward, done, info = env.step(action)

    if done:
        break

env.close()
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ## TODO: 직접 CartPole 에이전트 만들기
# https://gymnasium.farama.org/environments/classic_control/cart_pole/
# <br>
# 단순 프로그래밍으로 100 스텝까지 살아남는 에이전트를 만들어보세요.
#
# 100 스텝 이전에 끝났다면 위에서 작성한 CartPole 문제에 대한 대답을 참고하여 <br>더 오랜 시간 살아남을 수 있도록 만들어 보세요.
#
# 원래 목표는 500 스텝이었습니다 :)

# %%
env = wrap_env(gym.make("CartPole-v1"))
observation = env.reset()

i = 0
done = False
while not done:
    i += 1

    # 위치와 각도에 따라 행동 결정
    cart_position, cart_velocity, pole_angle, pole_velocity = observation

    # 간단한 규칙 기반 에이전트
    if pole_angle < 0:  # 막대가 왼쪽으로 기울어졌을 경우
        action = 0  # 왼쪽으로 움직이기
    else:  # 막대가 오른쪽으로 기울어졌을 경우
        action = 1  # 오른쪽으로 움직이기

    # 막대의 속도가 크면 더욱 적극적으로 움직임
    if pole_velocity > 0.5:
        action = 1  # 오른쪽
    elif pole_velocity < -0.5:
        action = 0  # 왼쪽

    # 행동에 따른 새로운 관측, 리워드, 에피소드 종료 여부, 종료에 관한 정보를 반환
    observation, reward, done, info = env.step(action)
    print(f"Step {i}: Previous action={action}, Observation={observation}, Reward={reward}")

    env.render()

    if done:
        break

env.close()
show_video()
# Out:
# Step 1: Previous action=1, Observation=[ 0.02728599  0.16620731  0.04284612 -0.29317044], Reward=1.0
# Step 2: Previous action=1, Observation=[ 0.03061013  0.36069302  0.03698271 -0.57203837], Reward=1.0
# Step 3: Previous action=0, Observation=[ 0.03782399  0.16507254  0.02554195 -0.26793785], Reward=1.0
# Step 4: Previous action=1, Observation=[ 0.04112544  0.35982083  0.02018319 -0.55245649], Reward=1.0
# Step 5: Previous action=0, Observation=[ 0.04832186  0.16442134  0.00913406 -0.25348349], Reward=1.0
# Step 6: Previous action=1, Observation=[ 0.05161029  0.35941168  0.00406439 -0.54327143], Reward=1.0
# Step 7: Previous action=0, Observation=[ 0.05879852  0.16423285 -0.00680104 -0.24931067], Reward=1.0
# Step 8: Previous action=0, Observation=[ 0.06208318 -0.03079132 -0.01178725  0.04121933], Reward=1.0
# Step 9: Previous action=0, Observation=[ 0.06146735 -0.22574228 -0.01096287  0.33016008], Reward=1.0
# Step 10: Previous action=0, Observation=[ 0.05695251 -0.42070647 -0.00435966  0.61936577], Reward=1.0
# Step 11: Previous action=1, Observation=[ 0.04853838 -0.2255239   0.00802765  0.32531296], Reward=1.0
# Step 12: Previous action=1, Observation=[ 0.0440279  -0.03051716  0.01453391  0.03517238], Reward=1.0
# Step 13: Previous action=1, Observation=[ 0.04341756  0.16439339  0.01523736 -0.25288974], Reward=1.0
# Step 14: Previous action=1, Observation=[ 0.04670542  0.35929449  0.01017956 -0.54072784], Reward=1.0
# Step 15: Previous action=0, Observation=[ 0.05389131  0.16403094 -0.00063499 -0.24485496], Reward=1.0
# Step 16: Previous action=0, Observation=[ 0.05717193 -0.03108194 -0.00553209  0.04762761], Reward=1.0
# Step 17: Previous action=0, Observation=[ 0.05655029 -0.22612413 -0.00457954  0.33855999], Reward=1.0
# Step 18: Previous action=0, Observation=[ 0.05202781 -0.42118061  0.00219166  0.62979527], Reward=1.0
# Step 19: Previous action=1, Observation=[ 0.0436042  -0.22608932  0.01478756  0.33780338], Reward=1.0
# Step 20: Previous action=1, Observation=[ 0.03908241 -0.03118088  0.02154363  0.04982007], Reward=1.0
# Step 21: Previous action=1, Observation=[ 0.03845879  0.16362564  0.02254003 -0.23598855], Reward=1.0
# Step 22: Previous action=1, Observation=[ 0.04173131  0.35841842  0.01782026 -0.52147731], Reward=1.0
# Step 23: Previous action=0, Observation=[ 0.04889968  0.16305023  0.00739072 -0.22323266], Reward=1.0
# Step 24: Previous action=1, Observation=[ 0.05216068  0.35806577  0.00292606 -0.51357513], Reward=1.0
# Step 25: Previous action=0, Observation=[ 0.059322    0.16290273 -0.00734544 -0.21997156], Reward=1.0
# Step 26: Previous action=0, Observation=[ 0.06258005 -0.03211346 -0.01174487  0.07038529], Reward=1.0
# Step 27: Previous action=0, Observation=[ 0.06193778 -0.22706508 -0.01033717  0.35933963], Reward=1.0
# Step 28: Previous action=0, Observation=[ 0.05739648 -0.42203857 -0.00315037  0.64874517], Reward=1.0
# Step 29: Previous action=1, Observation=[ 0.04895571 -0.22687287  0.00982453  0.35507187], Reward=1.0
# Step 30: Previous action=1, Observation=[ 0.04441825 -0.03189198  0.01692597  0.06550301], Reward=1.0
# Step 31: Previous action=1, Observation=[ 0.04378041  0.16298326  0.01823603 -0.22179199], Reward=1.0
# Step 32: Previous action=1, Observation=[ 0.04704008  0.35783988  0.01380019 -0.50866721], Reward=1.0
# Step 33: Previous action=0, Observation=[ 0.05419687  0.16252624  0.00362684 -0.21166753], Reward=1.0
# Step 34: Previous action=1, Observation=[ 0.0574474   0.35759615 -0.00060651 -0.50320418], Reward=1.0
# Step 35: Previous action=0, Observation=[ 0.06459932  0.16248275 -0.01067059 -0.21071245], Reward=1.0
# Step 36: Previous action=0, Observation=[ 0.06784898 -0.03248502 -0.01488484  0.07858546], Reward=1.0
# Step 37: Previous action=0, Observation=[ 0.06719928 -0.22739046 -0.01331313  0.36653526], Reward=1.0
# Step 38: Previous action=0, Observation=[ 0.06265147 -0.42232072 -0.00598242  0.6549908 ], Reward=1.0
# Step 39: Previous action=1, Observation=[ 0.05420505 -0.22711599  0.00711739  0.36043012], Reward=1.0
# Step 40: Previous action=1, Observation=[ 0.04966273 -0.03209593  0.01432599  0.06999993], Reward=1.0
# Step 41: Previous action=1, Observation=[ 0.04902081  0.16281773  0.01572599 -0.21812887], Reward=1.0
# Step 42: Previous action=1, Observation=[ 0.05227717  0.35771139  0.01136342 -0.50580995], Reward=1.0
# Step 43: Previous action=0, Observation=[ 0.0594314   0.16243117  0.00124722 -0.20956776], Reward=1.0
# Step 44: Previous action=1, Observation=[ 0.06268002  0.35753526 -0.00294414 -0.50185699], Reward=1.0
# Step 45: Previous action=0, Observation=[ 0.06983072  0.16245494 -0.01298128 -0.21010334], Reward=1.0
# Step 46: Previous action=0, Observation=[ 0.07307982 -0.03247902 -0.01718335  0.07845657], Reward=1.0
# Step 47: Previous action=0, Observation=[ 0.07243024 -0.22735048 -0.01561421  0.36566895], Reward=1.0
# Step 48: Previous action=0, Observation=[ 0.06788323 -0.4222471  -0.00830084  0.65338784], Reward=1.0
# Step 49: Previous action=1, Observation=[ 0.05943829 -0.22701055  0.00476692  0.35810269], Reward=1.0
# Step 50: Previous action=1, Observation=[ 0.05489808 -0.03195669  0.01192898  0.06692669], Reward=1.0
# Step 51: Previous action=1, Observation=[ 0.05425895  0.16299222  0.01326751 -0.22196883], Reward=1.0
# Step 52: Previous action=1, Observation=[ 0.05751879  0.35792205  0.00882813 -0.5104373 ], Reward=1.0
# Step 53: Previous action=0, Observation=[ 0.06467723  0.16267685 -0.00138061 -0.21498548], Reward=1.0
# Step 54: Previous action=0, Observation=[ 0.06793077 -0.03242533 -0.00568032  0.07726162], Reward=1.0
# Step 55: Previous action=0, Observation=[ 0.06728226 -0.22746539 -0.00413509  0.36814698], Reward=1.0
# Step 56: Previous action=0, Observation=[ 0.06273295 -0.42252835  0.00322785  0.65952319], Reward=1.0
# Step 57: Previous action=1, Observation=[ 0.05428239 -0.22745147  0.01641831  0.36785838], Reward=1.0
# Step 58: Previous action=1, Observation=[ 0.04973336 -0.03256661  0.02377548  0.08039727], Reward=1.0
# Step 59: Previous action=1, Observation=[ 0.04908203  0.16220659  0.02538343 -0.20469063], Reward=1.0
# Step 60: Previous action=1, Observation=[ 0.05232616  0.35695652  0.02128961 -0.48925949], Reward=1.0
# Step 61: Previous action=1, Observation=[ 0.05946529  0.55177175  0.01150442 -0.77515744], Reward=1.0
# Step 62: Previous action=0, Observation=[ 0.07050072  0.35649346 -0.00399873 -0.47887716], Reward=1.0
# Step 63: Previous action=0, Observation=[ 0.07763059  0.16142819 -0.01357627 -0.18745722], Reward=1.0
# Step 64: Previous action=0, Observation=[ 0.08085916 -0.03349692 -0.01732541  0.1009122 ], Reward=1.0
# Step 65: Previous action=0, Observation=[ 0.08018922 -0.22836634 -0.01530717  0.38807905], Reward=1.0
# Step 66: Previous action=0, Observation=[ 0.07562189 -0.42326771 -0.00754559  0.67589671], Reward=1.0
# Step 67: Previous action=1, Observation=[ 0.06715654 -0.22804172  0.00597235  0.38084769], Reward=1.0
# Step 68: Previous action=1, Observation=[ 0.0625957  -0.03300509  0.0135893   0.09005381], Reward=1.0
# Step 69: Previous action=1, Observation=[ 0.0619356   0.16191947  0.01539038 -0.1983109 ], Reward=1.0
# Step 70: Previous action=1, Observation=[ 0.06517399  0.35681795  0.01142416 -0.4860994 ], Reward=1.0
# Step 71: Previous action=1, Observation=[ 0.07231035  0.55177685  0.00170217 -0.77516004], Reward=1.0
# Step 72: Previous action=0, Observation=[ 0.08334589  0.35663153 -0.01380103 -0.48194204], Reward=1.0
# Step 73: Previous action=0, Observation=[ 0.09047852  0.16170707 -0.02343987 -0.19364057], Reward=1.0
# Step 74: Previous action=0, Observation=[ 0.09371266 -0.03307188 -0.02731268  0.09155689], Reward=1.0
# Step 75: Previous action=0, Observation=[ 0.09305122 -0.22779191 -0.02548155  0.37549909], Reward=1.0
# Step 76: Previous action=0, Observation=[ 0.08849538 -0.42254284 -0.01797156  0.66003987], Reward=1.0
# Step 77: Previous action=1, Observation=[ 0.08004453 -0.22717546 -0.00477077  0.36175277], Reward=1.0
# Step 78: Previous action=0, Observation=[ 0.07550102 -0.42222927  0.00246429  0.65292756], Reward=1.0
# Step 79: Previous action=1, Observation=[ 0.06705643 -0.22714172  0.01552284  0.36102163], Reward=1.0
# Step 80: Previous action=1, Observation=[ 0.0625136  -0.03224382  0.02274327  0.07327352], Reward=1.0
# Step 81: Previous action=1, Observation=[ 0.06186872  0.16254482  0.02420874 -0.21214793], Reward=1.0
# Step 82: Previous action=1, Observation=[ 0.06511962  0.35731243  0.01996578 -0.49709706], Reward=1.0
# Step 83: Previous action=1, Observation=[ 0.07226587  0.55214725  0.01002384 -0.78342149], Reward=1.0
# Step 84: Previous action=0, Observation=[ 0.08330881  0.35688899 -0.00564459 -0.48760185], Reward=1.0
# Step 85: Previous action=0, Observation=[ 0.09044659  0.16184713 -0.01539662 -0.19670323], Reward=1.0
# Step 86: Previous action=0, Observation=[ 0.09368353 -0.03305124 -0.01933069  0.09108326], Reward=1.0
# Step 87: Previous action=0, Observation=[ 0.09302251 -0.22789086 -0.01750902  0.37760521], Reward=1.0
# Step 88: Previous action=0, Observation=[ 0.08846469 -0.42275983 -0.00995692  0.66471646], Reward=1.0
# Step 89: Previous action=1, Observation=[ 0.08000949 -0.2275008   0.00333741  0.36891515], Reward=1.0
# Step 90: Previous action=1, Observation=[ 0.07545948 -0.03242642  0.01071571  0.07728642], Reward=1.0
# Step 91: Previous action=1, Observation=[ 0.07481095  0.16254029  0.01226144 -0.21199649], Reward=1.0
# Step 92: Previous action=1, Observation=[ 0.07806176  0.3574848   0.00802151 -0.50078651], Reward=1.0
# Step 93: Previous action=0, Observation=[ 0.08521145  0.1622507  -0.00199422 -0.20558648], Reward=1.0
# Step 94: Previous action=0, Observation=[ 0.08845647 -0.03284268 -0.00610595  0.08646671], Reward=1.0
# Step 95: Previous action=0, Observation=[ 0.08779961 -0.22787658 -0.00437661  0.37721696], Reward=1.0
# Step 96: Previous action=0, Observation=[ 0.08324208 -0.4229361   0.00316773  0.66851672], Reward=1.0
# Step 97: Previous action=1, Observation=[ 0.07478336 -0.22785834  0.01653806  0.37683286], Reward=1.0
# Step 98: Previous action=1, Observation=[ 0.07022619 -0.03297513  0.02407472  0.08940999], Reward=1.0
# Step 99: Previous action=1, Observation=[ 0.06956669  0.16179361  0.02586292 -0.19558118], Reward=1.0
# Step 100: Previous action=1, Observation=[ 0.07280256  0.35653625  0.02195129 -0.4799946 ], Reward=1.0
# Step 101: Previous action=1, Observation=[ 0.07993329  0.55134156  0.0123514  -0.765679  ], Reward=1.0
# Step 102: Previous action=0, Observation=[ 0.09096012  0.35605173 -0.00296218 -0.46913538], Reward=1.0
# Step 103: Previous action=0, Observation=[ 0.09808115  0.16097175 -0.01234489 -0.17738758], Reward=1.0
# Step 104: Previous action=0, Observation=[ 0.10130059 -0.03397138 -0.01589264  0.11137553], Reward=1.0
# Step 105: Previous action=0, Observation=[ 0.10062116 -0.22886203 -0.01366513  0.39900236], Reward=1.0
# Step 106: Previous action=0, Observation=[ 0.09604392 -0.42378749 -0.00568508  0.68734583], Reward=1.0
# Step 107: Previous action=1, Observation=[ 0.08756817 -0.22858709  0.00806184  0.39287855], Reward=1.0
# Step 108: Previous action=1, Observation=[ 0.08299643 -0.03358047  0.01591941  0.10274828], Reward=1.0
# Step 109: Previous action=1, Observation=[ 0.08232482  0.16130977  0.01797437 -0.18486992], Reward=1.0
# Step 110: Previous action=1, Observation=[ 0.08555101  0.35616999  0.01427698 -0.47182886], Reward=1.0
# Step 111: Previous action=1, Observation=[ 0.09267441  0.55108741  0.0048404  -0.7599779 ], Reward=1.0
# Step 112: Previous action=0, Observation=[ 0.10369616  0.3558991  -0.01035916 -0.4657758 ], Reward=1.0
# Step 113: Previous action=0, Observation=[ 0.11081414  0.16092504 -0.01967468 -0.17637594], Reward=1.0
# Step 114: Previous action=0, Observation=[ 0.11403264 -0.0339099  -0.02320219  0.11003592], Reward=1.0
# Step 115: Previous action=0, Observation=[ 0.11335445 -0.22869182 -0.02100148  0.39530933], Reward=1.0
# Step 116: Previous action=0, Observation=[ 0.10878061 -0.42350958 -0.01309529  0.68129755], Reward=1.0
# Step 117: Previous action=1, Observation=[ 0.10031042 -0.22820823  0.00053066  0.38452073], Reward=1.0
# Step 118: Previous action=1, Observation=[ 0.09574625 -0.03309381  0.00822108  0.09200517], Reward=1.0
# Step 119: Previous action=1, Observation=[ 0.09508438  0.16190935  0.01006118 -0.19807271], Reward=1.0
# Step 120: Previous action=1, Observation=[ 0.09832256  0.35688596  0.00609973 -0.48756489], Reward=1.0
# Step 121: Previous action=1, Observation=[ 0.10546028  0.55192131 -0.00365157 -0.77831918], Reward=1.0
# Step 122: Previous action=0, Observation=[ 0.11649871  0.35684976 -0.01921796 -0.48678736], Reward=1.0
# Step 123: Previous action=0, Observation=[ 0.1236357   0.16200418 -0.0289537  -0.20022269], Reward=1.0
# Step 124: Previous action=0, Observation=[ 0.12687579 -0.03269196 -0.03295816  0.08318792], Reward=1.0
# Step 125: Previous action=0, Observation=[ 0.12622195 -0.22732634 -0.0312944   0.365293  ], Reward=1.0
# Step 126: Previous action=0, Observation=[ 0.12167542 -0.42198991 -0.02398854  0.64794632], Reward=1.0
# Step 127: Previous action=1, Observation=[ 0.11323562 -0.22654211 -0.01102961  0.34780702], Reward=1.0
# Step 128: Previous action=0, Observation=[ 0.10870478 -0.42150546 -0.00407347  0.63699162], Reward=1.0
# Step 129: Previous action=1, Observation=[ 0.10027467 -0.22632694  0.00866636  0.34302867], Reward=1.0
# Step 130: Previous action=1, Observation=[ 0.09574813 -0.03132935  0.01552693  0.05309114], Reward=1.0
# Step 131: Previous action=1, Observation=[ 0.09512155  0.16356657  0.01658876 -0.23465275], Reward=1.0
# Step 132: Previous action=1, Observation=[ 0.09839288  0.35844762  0.0118957  -0.52205724], Reward=1.0
# Step 133: Previous action=0, Observation=[ 0.10556183  0.16316027  0.00145456 -0.22564969], Reward=1.0
# Step 134: Previous action=1, Observation=[ 0.10882504  0.3582614  -0.00305844 -0.51787344], Reward=1.0
# Step 135: Previous action=0, Observation=[ 0.11599026  0.16318265 -0.01341591 -0.22615585], Reward=1.0
# Step 136: Previous action=0, Observation=[ 0.11925392 -0.03174503 -0.01793902  0.06226519], Reward=1.0
# Step 137: Previous action=0, Observation=[ 0.11861902 -0.22660524 -0.01669372  0.34923469], Reward=1.0
# Step 138: Previous action=0, Observation=[ 0.11408691 -0.42148584 -0.00970903  0.63660713], Reward=1.0
# Step 139: Previous action=1, Observation=[ 0.1056572  -0.22622984  0.00302312  0.34088252], Reward=1.0
# Step 140: Previous action=1, Observation=[ 0.1011326  -0.03115103  0.00984077  0.04915445], Reward=1.0
# Step 141: Previous action=1, Observation=[ 0.10050958  0.16382844  0.01082386 -0.24040746], Reward=1.0
# Step 142: Previous action=1, Observation=[ 0.10378615  0.35879411  0.00601571 -0.52965669], Reward=1.0
# Step 143: Previous action=0, Observation=[ 0.11096203  0.16358805 -0.00457743 -0.23508429], Reward=1.0
# Step 144: Previous action=0, Observation=[ 0.11423379 -0.0314682  -0.00927911  0.05615127], Reward=1.0
# Step 145: Previous action=0, Observation=[ 0.11360443 -0.22645588 -0.00815609  0.34589218], Reward=1.0
# Step 146: Previous action=0, Observation=[ 0.10907531 -0.42146087 -0.00123824  0.63599207], Reward=1.0
# Step 147: Previous action=1, Observation=[ 0.10064609 -0.22632167  0.0114816   0.34291946], Reward=1.0
# Step 148: Previous action=1, Observation=[ 0.09611966 -0.03136493  0.01833999  0.05387914], Reward=1.0
# Step 149: Previous action=1, Observation=[ 0.09549236  0.16348931  0.01941757 -0.23296142], Reward=1.0
# Step 150: Previous action=1, Observation=[ 0.09876215  0.35832851  0.01475834 -0.51945672], Reward=1.0
# Step 151: Previous action=0, Observation=[ 0.10592872  0.16300193  0.00436921 -0.22215996], Reward=1.0
# Step 152: Previous action=1, Observation=[ 1.09188754e-01  3.58061161e-01 -7.39914894e-05 -5.13461469e-01], Reward=1.0
# Step 153: Previous action=0, Observation=[ 0.11634998  0.16294025 -0.01034322 -0.22080186], Reward=1.0
# Step 154: Previous action=0, Observation=[ 0.11960878 -0.03203234 -0.01475926  0.06860053], Reward=1.0
# Step 155: Previous action=0, Observation=[ 0.11896814 -0.22693961 -0.01338725  0.35659053], Reward=1.0
# Step 156: Previous action=0, Observation=[ 0.11442934 -0.4218687  -0.00625544  0.64502223], Reward=1.0
# Step 157: Previous action=1, Observation=[ 0.10599197 -0.22666014  0.00664501  0.35037603], Reward=1.0
# Step 158: Previous action=1, Observation=[ 0.10145877 -0.03163332  0.01365253  0.05979587], Reward=1.0
# Step 159: Previous action=1, Observation=[ 0.1008261   0.16329025  0.01484845 -0.22854851], Reward=1.0
# Step 160: Previous action=1, Observation=[ 0.10409191  0.3581969   0.01027748 -0.51651097], Reward=1.0
# Step 161: Previous action=0, Observation=[ 1.11255844e-01  1.62931748e-01 -5.27438563e-05 -2.20607188e-01], Reward=1.0
# Step 162: Previous action=0, Observation=[ 0.11451448 -0.03218945 -0.00446489  0.0720591 ], Reward=1.0
# Step 163: Previous action=0, Observation=[ 0.11387069 -0.22724711 -0.00302371  0.36333   ], Reward=1.0
# Step 164: Previous action=0, Observation=[ 0.10932575 -0.42232595  0.00424289  0.65505796], Reward=1.0
# Step 165: Previous action=1, Observation=[ 0.10087923 -0.22726333  0.01734405  0.36371407], Reward=1.0
# Step 166: Previous action=1, Observation=[ 0.09633396 -0.03239212  0.02461833  0.07655011], Reward=1.0
# Step 167: Previous action=1, Observation=[ 0.09568612  0.16236842  0.02614934 -0.20826511], Reward=1.0
# Step 168: Previous action=1, Observation=[ 0.09893349  0.35710689  0.02198403 -0.49258592], Reward=1.0
# Step 169: Previous action=1, Observation=[ 0.10607563  0.55191197  0.01213232 -0.77826015], Reward=1.0
# Step 170: Previous action=0, Observation=[ 0.11711386  0.35662531 -0.00343289 -0.48178491], Reward=1.0
# Step 171: Previous action=0, Observation=[ 0.12424637  0.16155199 -0.01306858 -0.19018591], Reward=1.0
# Step 172: Previous action=0, Observation=[ 0.12747741 -0.03338059 -0.0168723   0.09834593], Reward=1.0
# Step 173: Previous action=0, Observation=[ 0.1268098  -0.22825671 -0.01490538  0.38565829], Reward=1.0
# Step 174: Previous action=0, Observation=[ 0.12224466 -0.42316393 -0.00719222  0.67360461], Reward=1.0
# Step 175: Previous action=1, Observation=[ 0.11378139 -0.22794275  0.00627987  0.37866593], Reward=1.0
# Step 176: Previous action=1, Observation=[ 0.10922253 -0.03291055  0.01385319  0.08796966], Reward=1.0
# Step 177: Previous action=1, Observation=[ 0.10856432  0.16201012  0.01561259 -0.20031058], Reward=1.0
# Step 178: Previous action=1, Observation=[ 0.11180452  0.35690534  0.01160637 -0.48802786], Reward=1.0
# Step 179: Previous action=1, Observation=[ 0.11894263  0.55186163  0.00184582 -0.7770304 ], Reward=1.0
# Step 180: Previous action=0, Observation=[ 0.12997986  0.35671434 -0.01369479 -0.4837673 ], Reward=1.0
# Step 181: Previous action=0, Observation=[ 0.13711415  0.16178832 -0.02337014 -0.19543182], Reward=1.0
# Step 182: Previous action=0, Observation=[ 0.14034992 -0.03299168 -0.02727877  0.0897882 ], Reward=1.0
# Step 183: Previous action=0, Observation=[ 0.13969008 -0.22771223 -0.02548301  0.37374138], Reward=1.0
# Step 184: Previous action=0, Observation=[ 0.13513584 -0.42246309 -0.01800818  0.65828164], Reward=1.0
# Step 185: Previous action=1, Observation=[ 0.12668658 -0.22709518 -0.00484255  0.35998317], Reward=1.0
# Step 186: Previous action=0, Observation=[ 0.12214467 -0.42214796  0.00235711  0.65113521], Reward=1.0
# Step 187: Previous action=1, Observation=[ 0.11370171 -0.22705892  0.01537982  0.35919545], Reward=1.0
# Step 188: Previous action=1, Observation=[ 0.10916053 -0.03215894  0.02256373  0.07140154], Reward=1.0
# Step 189: Previous action=1, Observation=[ 0.10851735  0.16263238  0.02399176 -0.21407789], Reward=1.0
# Step 190: Previous action=1, Observation=[ 0.11177     0.35740326  0.0197102  -0.49909723], Reward=1.0
# Step 191: Previous action=1, Observation=[ 0.11891807  0.55224186  0.00972826 -0.78550394], Reward=1.0
# Step 192: Previous action=0, Observation=[ 0.1299629   0.35698761 -0.00598182 -0.48977636], Reward=1.0
# Step 193: Previous action=0, Observation=[ 0.13710266  0.16195055 -0.01577735 -0.19898466], Reward=1.0
# Step 194: Previous action=0, Observation=[ 0.14034167 -0.03294222 -0.01975704  0.08867978], Reward=1.0
# Step 195: Previous action=0, Observation=[ 0.13968282 -0.22777549 -0.01798345  0.37506445], Reward=1.0
# Step 196: Previous action=0, Observation=[ 0.13512731 -0.42263745 -0.01048216  0.66202327], Reward=1.0
# Step 197: Previous action=1, Observation=[ 0.12667456 -0.22737123  0.00275831  0.36605833], Reward=1.0
# Step 198: Previous action=1, Observation=[ 0.12212714 -0.03228858  0.01007947  0.07424642], Reward=1.0
# Step 199: Previous action=1, Observation=[ 0.12148137  0.16268743  0.0115644  -0.21523943], Reward=1.0
# Step 200: Previous action=1, Observation=[ 0.12473512  0.35764216  0.00725961 -0.50425211], Reward=1.0
# Step 201: Previous action=0, Observation=[ 0.13188796  0.16241865 -0.00282543 -0.20929026], Reward=1.0
# Step 202: Previous action=0, Observation=[ 0.13513633 -0.03266279 -0.00701123  0.08250006], Reward=1.0
# Step 203: Previous action=0, Observation=[ 0.13448308 -0.22768353 -0.00536123  0.3729627 ], Reward=1.0
# Step 204: Previous action=0, Observation=[ 0.12992941 -0.42272892  0.00209802  0.66395037], Reward=1.0
# Step 205: Previous action=1, Observation=[ 0.12147483 -0.22763621  0.01537703  0.37192878], Reward=1.0
# Step 206: Previous action=1, Observation=[ 0.1169221  -0.03273605  0.0228156   0.08413377], Reward=1.0
# Step 207: Previous action=1, Observation=[ 0.11626738  0.16205154  0.02449828 -0.20126437], Reward=1.0
# Step 208: Previous action=1, Observation=[ 0.11950841  0.35681471  0.02047299 -0.48611968], Reward=1.0
# Step 209: Previous action=1, Observation=[ 0.12664471  0.55164187  0.0107506  -0.77228055], Reward=1.0
# Step 210: Previous action=0, Observation=[ 0.13767755  0.35637366 -0.00469501 -0.47623454], Reward=1.0
# Step 211: Previous action=0, Observation=[ 0.14480502  0.16131832 -0.0142197  -0.18503508], Reward=1.0
# Step 212: Previous action=0, Observation=[ 0.14803139 -0.03359732 -0.01792041  0.10312837], Reward=1.0
# Step 213: Previous action=0, Observation=[ 0.14735944 -0.22845793 -0.01585784  0.39010403], Reward=1.0
# Step 214: Previous action=0, Observation=[ 0.14279028 -0.42335126 -0.00805576  0.67774526], Reward=1.0
# Step 215: Previous action=1, Observation=[ 0.13432326 -0.22811832  0.00549915  0.38253699], Reward=1.0
# Step 216: Previous action=1, Observation=[ 0.12976089 -0.03307488  0.01314989  0.09159299], Reward=1.0
# Step 217: Previous action=1, Observation=[ 0.12909939  0.16185615  0.01498175 -0.19691231], Reward=1.0
# Step 218: Previous action=1, Observation=[ 0.13233651  0.35676063  0.0110435  -0.48483177], Reward=1.0
# Step 219: Previous action=1, Observation=[ 0.13947173  0.55172501  0.00134687 -0.77401378], Reward=1.0
# Step 220: Previous action=0, Observation=[ 0.15050623  0.35658456 -0.01413341 -0.48090738], Reward=1.0
# Step 221: Previous action=0, Observation=[ 0.15763792  0.16166493 -0.02375156 -0.19271223], Reward=1.0
# Step 222: Previous action=0, Observation=[ 0.16087122 -0.03310934 -0.0276058   0.09238447], Reward=1.0
# Step 223: Previous action=0, Observation=[ 0.16020903 -0.22782496 -0.02575811  0.37623154], Reward=1.0
# Step 224: Previous action=0, Observation=[ 0.15565253 -0.42257177 -0.01823348  0.6606828 ], Reward=1.0
# Step 225: Previous action=1, Observation=[ 0.1472011  -0.22720089 -0.00501983  0.36231486], Reward=1.0
# Step 226: Previous action=0, Observation=[ 0.14265708 -0.42225114  0.00222647  0.65341072], Reward=1.0
# Step 227: Previous action=1, Observation=[ 0.13421206 -0.22716026  0.01529469  0.36142971], Reward=1.0
# Step 228: Previous action=1, Observation=[ 0.12966885 -0.03225901  0.02252328  0.07360849], Reward=1.0
# Step 229: Previous action=1, Observation=[ 0.12902367  0.16253292  0.02399545 -0.21188402], Reward=1.0
# Step 230: Previous action=1, Observation=[ 0.13227433  0.35730372  0.01975777 -0.49690213], Reward=1.0
# Step 231: Previous action=1, Observation=[ 0.1394204   0.55214159  0.00981973 -0.78329347], Reward=1.0
# Step 232: Previous action=0, Observation=[ 0.15046323  0.35688607 -0.00584614 -0.48753737], Reward=1.0
# Step 233: Previous action=0, Observation=[ 0.15760096  0.16184709 -0.01559689 -0.19670266], Reward=1.0
# Step 234: Previous action=0, Observation=[ 0.1608379  -0.03304833 -0.01953094  0.09101963], Reward=1.0
# Step 235: Previous action=0, Observation=[ 0.16017693 -0.22788497 -0.01771055  0.37747711], Reward=1.0
# Step 236: Previous action=0, Observation=[ 0.15561923 -0.42275097 -0.01016101  0.66452364], Reward=1.0
# Step 237: Previous action=1, Observation=[ 0.14716421 -0.22748916  0.00312946  0.36865876], Reward=1.0
# Step 238: Previous action=1, Observation=[ 0.14261443 -0.03241181  0.01050264  0.07696423], Reward=1.0
# Step 239: Previous action=1, Observation=[ 0.14196619  0.16255801  0.01204192 -0.21238666], Reward=1.0
# Step 240: Previous action=1, Observation=[ 0.14521735  0.35750574  0.00779419 -0.50124681], Reward=1.0
# Step 241: Previous action=0, Observation=[ 0.15236747  0.16227479 -0.00223075 -0.20611781], Reward=1.0
# Step 242: Previous action=0, Observation=[ 0.15561296 -0.03281519 -0.0063531   0.08586059], Reward=1.0
# Step 243: Previous action=0, Observation=[ 0.15495666 -0.2278455  -0.00463589  0.37653235], Reward=1.0
# Step 244: Previous action=0, Observation=[ 0.15039975 -0.4229013   0.00289476  0.66774996], Reward=1.0
# Step 245: Previous action=1, Observation=[ 0.14194172 -0.22781972  0.01624976  0.37597988], Reward=1.0
# Step 246: Previous action=1, Observation=[ 0.13738533 -0.0329323   0.02376935  0.08846456], Reward=1.0
# Step 247: Previous action=1, Observation=[ 0.13672668  0.16184102  0.02553865 -0.19662536], Reward=1.0
# Step 248: Previous action=1, Observation=[ 0.1399635   0.35658854  0.02160614 -0.48114384], Reward=1.0
# Step 249: Previous action=1, Observation=[ 0.14709527  0.55139895  0.01198326 -0.76693954], Reward=1.0
# Step 250: Previous action=0, Observation=[ 0.15812325  0.35611409 -0.00335553 -0.47051028], Reward=1.0
# Step 251: Previous action=0, Observation=[ 0.16524554  0.1610397  -0.01276573 -0.17888686], Reward=1.0
# Step 252: Previous action=0, Observation=[ 0.16846633 -0.03389727 -0.01634347  0.10974174], Reward=1.0
# Step 253: Previous action=0, Observation=[ 0.16778838 -0.22878126 -0.01414864  0.39722391], Reward=1.0
# Step 254: Previous action=0, Observation=[ 0.16321276 -0.42369964 -0.00620416  0.68541267], Reward=1.0
# Step 255: Previous action=1, Observation=[ 0.15473877 -0.22849211  0.00750409  0.39078299], Reward=1.0
# Step 256: Previous action=1, Observation=[ 0.15016892 -0.03347746  0.01531975  0.10047544], Reward=1.0
# Step 257: Previous action=1, Observation=[ 0.14949937  0.16142162  0.01732926 -0.18733505], Reward=1.0
# Step 258: Previous action=1, Observation=[ 0.15272781  0.35629141  0.01358256 -0.47450129], Reward=1.0
# Step 259: Previous action=1, Observation=[ 0.15985364  0.55121894  0.00409254 -0.76287247], Reward=1.0
# Step 260: Previous action=0, Observation=[ 0.17087801  0.35604086 -0.01116491 -0.4689046 ], Reward=1.0
# Step 261: Previous action=0, Observation=[ 0.17799883  0.1610784  -0.02054301 -0.17976155], Reward=1.0
# Step 262: Previous action=0, Observation=[ 0.1812204  -0.03374365 -0.02413824  0.10637064], Reward=1.0
# Step 263: Previous action=0, Observation=[ 0.18054553 -0.22851152 -0.02201082  0.39134139], Reward=1.0
# Step 264: Previous action=0, Observation=[ 0.1759753  -0.42331429 -0.014184    0.67700411], Reward=1.0
# Step 265: Previous action=1, Observation=[ 0.16750901 -0.22799817 -0.00064391  0.37988944], Reward=1.0
# Step 266: Previous action=0, Observation=[ 0.16294905 -0.42311097  0.00695388  0.67236927], Reward=1.0
# Step 267: Previous action=1, Observation=[ 0.15448683 -0.22808637  0.02040126  0.38188386], Reward=1.0
# Step 268: Previous action=1, Observation=[ 0.1499251  -0.03325995  0.02803894  0.0957026 ], Reward=1.0
# Step 269: Previous action=1, Observation=[ 0.1492599   0.16144915  0.02995299 -0.18800388], Reward=1.0
# Step 270: Previous action=1, Observation=[ 0.15248888  0.35613004  0.02619291 -0.47108937], Reward=1.0
# Step 271: Previous action=1, Observation=[ 0.15961148  0.55087242  0.01677113 -0.75540289], Reward=1.0
# Step 272: Previous action=0, Observation=[ 0.17062893  0.35552334  0.00166307 -0.45749001], Reward=1.0
# Step 273: Previous action=1, Observation=[ 0.1777394   0.55062174 -0.00748673 -0.74964827], Reward=1.0
# Step 274: Previous action=0, Observation=[ 0.18875183  0.35560386 -0.0224797  -0.45933071], Reward=1.0
# Step 275: Previous action=0, Observation=[ 0.19586391  0.16080676 -0.03166631 -0.17381737], Reward=1.0
# Step 276: Previous action=0, Observation=[ 0.19908005 -0.03384801 -0.03514266  0.10871006], Reward=1.0
# Step 277: Previous action=0, Observation=[ 0.19840309 -0.2284492  -0.03296846  0.39010181], Reward=1.0
# Step 278: Previous action=0, Observation=[ 0.1938341  -0.4230881  -0.02516642  0.67221053], Reward=1.0
# Step 279: Previous action=1, Observation=[ 0.18537234 -0.22762553 -0.01172221  0.37171136], Reward=1.0
# Step 280: Previous action=0, Observation=[ 0.18081983 -0.422579   -0.00428799  0.66067523], Reward=1.0
# Step 281: Previous action=1, Observation=[ 0.17236825 -0.22739764  0.00892552  0.36664522], Reward=1.0
# Step 282: Previous action=1, Observation=[ 0.1678203  -0.03240366  0.01625842  0.07678996], Reward=1.0
# Step 283: Previous action=1, Observation=[ 0.16717222  0.16248149  0.01779422 -0.21071936], Reward=1.0
# Step 284: Previous action=1, Observation=[ 0.17042185  0.35734456  0.01357984 -0.49773646], Reward=1.0
# Step 285: Previous action=1, Observation=[ 0.17756875  0.55227243  0.00362511 -0.78610896], Reward=1.0
# Step 286: Previous action=0, Observation=[ 0.18861419  0.35710086 -0.01209707 -0.49228775], Reward=1.0
# Step 287: Previous action=0, Observation=[ 0.19575621  0.16215161 -0.02194283 -0.20344173], Reward=1.0
# Step 288: Previous action=0, Observation=[ 0.19899924 -0.03264977 -0.02601166  0.08223933], Reward=1.0
# Step 289: Previous action=0, Observation=[ 0.19834625 -0.22738938 -0.02436688  0.36660336], Reward=1.0
# Step 290: Previous action=0, Observation=[ 0.19379846 -0.42215675 -0.01703481  0.65150453], Reward=1.0
# Step 291: Previous action=1, Observation=[ 0.18535533 -0.22680174 -0.00400472  0.35350655], Reward=1.0
# Step 292: Previous action=0, Observation=[ 0.18081929 -0.42186652  0.00306541  0.64492398], Reward=1.0
# Step 293: Previous action=1, Observation=[ 0.17238196 -0.22678742  0.01596389  0.35320794], Reward=1.0
# Step 294: Previous action=1, Observation=[ 0.16784621 -0.03189607  0.02302805  0.06560135], Reward=1.0
# Step 295: Previous action=1, Observation=[ 0.16720829  0.16288829  0.02434008 -0.21972807], Reward=1.0
# Step 296: Previous action=1, Observation=[ 0.17046606  0.35765401  0.01994552 -0.50463484], Reward=1.0
# Step 297: Previous action=0, Observation=[ 0.17761914  0.16225673  0.00985282 -0.20573362], Reward=1.0
# Step 298: Previous action=1, Observation=[ 0.18086427  0.35723641  0.00573815 -0.49529226], Reward=1.0
# Step 299: Previous action=1, Observation=[ 0.188009    0.55227697 -0.0041677  -0.78616128], Reward=1.0
# Step 300: Previous action=0, Observation=[ 0.19905454  0.35721252 -0.01989092 -0.49479245], Reward=1.0
# Step 301: Previous action=0, Observation=[ 0.20619879  0.16237665 -0.02978677 -0.208444  ], Reward=1.0
# Step 302: Previous action=0, Observation=[ 0.20944632 -0.03230699 -0.03395565  0.07469591], Reward=1.0
# Step 303: Previous action=0, Observation=[ 0.20880018 -0.22692612 -0.03246173  0.35647527], Reward=1.0
# Step 304: Previous action=0, Observation=[ 0.20426166 -0.42157187 -0.02533223  0.638748  ], Reward=1.0
# Step 305: Previous action=1, Observation=[ 0.19583022 -0.22610603 -0.01255727  0.33819644], Reward=1.0
# Step 306: Previous action=0, Observation=[ 0.1913081  -0.42104706 -0.00579334  0.62689319], Reward=1.0
# Step 307: Previous action=1, Observation=[ 0.18288716 -0.22584473  0.00674452  0.33239137], Reward=1.0
# Step 308: Previous action=1, Observation=[ 0.17837027 -0.03081942  0.01339235  0.04184295], Reward=1.0
# Step 309: Previous action=1, Observation=[ 0.17775388  0.16410795  0.01422921 -0.24658466], Reward=1.0
# Step 310: Previous action=1, Observation=[ 0.18103604  0.35902382  0.00929752 -0.53474562], Reward=1.0
# Step 311: Previous action=0, Observation=[ 0.18821651  0.16377236 -0.00139739 -0.23914766], Reward=1.0
# Step 312: Previous action=0, Observation=[ 0.19149196 -0.0313296  -0.00618035  0.05309416], Reward=1.0
# Step 313: Previous action=0, Observation=[ 0.19086537 -0.22636239 -0.00511846  0.34382075], Reward=1.0
# Step 314: Previous action=0, Observation=[ 0.18633812 -0.42141115  0.00175795  0.63488524], Reward=1.0
# Step 315: Previous action=1, Observation=[ 0.1779099  -0.22631376  0.01445566  0.34275645], Reward=1.0
# Step 316: Previous action=1, Observation=[ 0.17338362 -0.03140042  0.02131078  0.05466679], Reward=1.0
# Step 317: Previous action=1, Observation=[ 0.17275561  0.16340958  0.02240412 -0.23121697], Reward=1.0
# Step 318: Previous action=1, Observation=[ 0.17602381  0.35820435  0.01777978 -0.51674952], Reward=1.0
# Step 319: Previous action=0, Observation=[ 0.18318789  0.16283661  0.00744479 -0.21851726], Reward=1.0
# Step 320: Previous action=1, Observation=[ 0.18644462  0.35785136  0.00307445 -0.50884252], Reward=1.0
# Step 321: Previous action=0, Observation=[ 0.19360165  0.16268622 -0.00710241 -0.21519232], Reward=1.0
# Step 322: Previous action=0, Observation=[ 0.19685538 -0.03233347 -0.01140625  0.07524176], Reward=1.0
# Step 323: Previous action=0, Observation=[ 0.19620871 -0.22729006 -0.00990142  0.36430425], Reward=1.0
# Step 324: Previous action=0, Observation=[ 0.19166291 -0.42226991 -0.00261533  0.65384871], Reward=1.0
# Step 325: Previous action=1, Observation=[ 0.18321751 -0.22711164  0.01046164  0.3603434 ], Reward=1.0
# Step 326: Previous action=1, Observation=[ 0.17867527 -0.03213994  0.01766851  0.07097754], Reward=1.0
# Step 327: Previous action=1, Observation=[ 0.17803248  0.1627243   0.01908806 -0.21607894], Reward=1.0
# Step 328: Previous action=1, Observation=[ 0.18128696  0.35756825  0.01476648 -0.50268006], Reward=1.0
# Step 329: Previous action=0, Observation=[ 0.18843833  0.16224131  0.00471288 -0.20538041], Reward=1.0
# Step 330: Previous action=1, Observation=[ 0.19168315  0.35729555  0.00060527 -0.49657294], Reward=1.0
# Step 331: Previous action=1, Observation=[ 0.19882906  0.55240896 -0.00932619 -0.78906505], Reward=1.0
# Step 332: Previous action=0, Observation=[ 0.20987724  0.35741633 -0.02510749 -0.49933068], Reward=1.0
# Step 333: Previous action=0, Observation=[ 0.21702557  0.16265718 -0.0350941  -0.21466486], Reward=1.0
# Step 334: Previous action=0, Observation=[ 0.22027871 -0.03194593 -0.0393874   0.06674453], Reward=1.0
# Step 335: Previous action=0, Observation=[ 0.21963979 -0.2264817  -0.03805251  0.34674495], Reward=1.0
# Step 336: Previous action=0, Observation=[ 0.21511016 -0.4210423  -0.03111761  0.62718986], Reward=1.0
# Step 337: Previous action=1, Observation=[ 0.20668931 -0.22550016 -0.01857381  0.32487154], Reward=1.0
# Step 338: Previous action=0, Observation=[ 0.20217931 -0.42035279 -0.01207638  0.61163968], Reward=1.0
# Step 339: Previous action=1, Observation=[ 1.93772255e-01 -2.25064154e-01  1.56413889e-04  3.15177720e-01], Reward=1.0
# Step 340: Previous action=1, Observation=[ 0.18927097 -0.02994443  0.00645997  0.02254412], Reward=1.0
# Step 341: Previous action=1, Observation=[ 0.18867208  0.16508429  0.00691085 -0.26809363], Reward=1.0
# Step 342: Previous action=1, Observation=[ 0.19197377  0.36010693  0.00154898 -0.55858884], Reward=1.0
# Step 343: Previous action=0, Observation=[ 0.19917591  0.16496327 -0.0096228  -0.2654183 ], Reward=1.0
# Step 344: Previous action=0, Observation=[ 0.20247517 -0.03002002 -0.01493116  0.02421404], Reward=1.0
# Step 345: Previous action=0, Observation=[ 0.20187477 -0.2249247  -0.01444688  0.31214887], Reward=1.0
# Step 346: Previous action=0, Observation=[ 0.19737628 -0.41983789 -0.00820391  0.60024091], Reward=1.0
# Step 347: Previous action=1, Observation=[ 0.18897952 -0.22460213  0.00380091  0.30498521], Reward=1.0
# Step 348: Previous action=1, Observation=[ 0.18448748 -0.02953455  0.00990062  0.01350342], Reward=1.0
# Step 349: Previous action=1, Observation=[ 0.18389679  0.16544402  0.01017068 -0.27603938], Reward=1.0
# Step 350: Previous action=1, Observation=[ 0.18720567  0.3604194   0.0046499  -0.56549719], Reward=1.0
# Step 351: Previous action=0, Observation=[ 0.19441406  0.16523252 -0.00666005 -0.27135298], Reward=1.0
# Step 352: Previous action=0, Observation=[ 0.19771871 -0.02979376 -0.01208711  0.01922192], Reward=1.0
# Step 353: Previous action=0, Observation=[ 0.19712283 -0.2247403  -0.01170267  0.30806685], Reward=1.0
# Step 354: Previous action=0, Observation=[ 0.19262803 -0.41969357 -0.00554133  0.59703622], Reward=1.0
# Step 355: Previous action=1, Observation=[ 0.18423415 -0.22449451  0.00639939  0.30261299], Reward=1.0
# Step 356: Previous action=1, Observation=[ 0.17974426 -0.02946435  0.01245165  0.01195514], Reward=1.0
# Step 357: Previous action=1, Observation=[ 0.17915498  0.16547684  0.01269076 -0.27677328], Reward=1.0
# Step 358: Previous action=1, Observation=[ 0.18246451  0.36041546  0.00715529 -0.56542668], Reward=1.0
# Step 359: Previous action=0, Observation=[ 0.18967282  0.16519385 -0.00415324 -0.27049813], Reward=1.0
# Step 360: Previous action=0, Observation=[ 0.1929767  -0.02986858 -0.00956321  0.02087195], Reward=1.0
# Step 361: Previous action=0, Observation=[ 0.19237933 -0.22485209 -0.00914577  0.3105223 ], Reward=1.0
# Step 362: Previous action=0, Observation=[ 0.18788229 -0.41984255 -0.00293532  0.60030694], Reward=1.0
# Step 363: Previous action=1, Observation=[ 0.17948543 -0.22467966  0.00907082  0.30670088], Reward=1.0
# Step 364: Previous action=1, Observation=[ 0.17499184 -0.02968813  0.01520484  0.01689241], Reward=1.0
# Step 365: Previous action=1, Observation=[ 0.17439808  0.1652125   0.01554268 -0.2709547 ], Reward=1.0
# Step 366: Previous action=1, Observation=[ 0.17770233  0.36010925  0.01012359 -0.55869515], Reward=1.0
# Step 367: Previous action=0, Observation=[ 0.18490451  0.16484667 -0.00105031 -0.26284   ], Reward=1.0
# Step 368: Previous action=0, Observation=[ 0.18820145 -0.03026027 -0.00630711  0.02951146], Reward=1.0
# Step 369: Previous action=0, Observation=[ 0.18759624 -0.22529121 -0.00571688  0.32019777], Reward=1.0
# Step 370: Previous action=0, Observation=[ 0.18309042 -0.42033128  0.00068707  0.61107234], Reward=1.0
# Step 371: Previous action=1, Observation=[ 0.17468379 -0.22521894  0.01290852  0.3186059 ], Reward=1.0
# Step 372: Previous action=1, Observation=[ 0.17017941 -0.03028319  0.01928064  0.03002164], Reward=1.0
# Step 373: Previous action=1, Observation=[ 0.16957375  0.16455703  0.01988107 -0.25651622], Reward=1.0
# Step 374: Previous action=1, Observation=[ 0.17286489  0.35938957  0.01475074 -0.54286264], Reward=1.0
# Step 375: Previous action=0, Observation=[ 0.18005268  0.16406346  0.00389349 -0.24556877], Reward=1.0
# Step 376: Previous action=1, Observation=[ 0.18333395  0.35912958 -0.00101788 -0.53702106], Reward=1.0
# Step 377: Previous action=0, Observation=[ 0.19051654  0.16402196 -0.01175831 -0.24465903], Reward=1.0
# Step 378: Previous action=0, Observation=[ 0.19379698 -0.03093009 -0.01665149  0.04429196], Reward=1.0
# Step 379: Previous action=0, Observation=[ 0.19317838 -0.22580936 -0.01576565  0.33167503], Reward=1.0
# Step 380: Previous action=0, Observation=[ 0.18866219 -0.42070339 -0.00913215  0.61934484], Reward=1.0
# Step 381: Previous action=1, Observation=[ 0.18024812 -0.22545509  0.00325475  0.32379978], Reward=1.0
# Step 382: Previous action=1, Observation=[ 0.17573902 -0.03037963  0.00973075  0.03214505], Reward=1.0
# Step 383: Previous action=1, Observation=[ 0.17513143  0.16460143  0.01037365 -0.25745191], Reward=1.0
# Step 384: Previous action=1, Observation=[ 0.17842346  0.35957376  0.00522461 -0.54684486], Reward=1.0
# Step 385: Previous action=0, Observation=[ 0.18561493  0.16437879 -0.00571229 -0.25252039], Reward=1.0
# Step 386: Previous action=0, Observation=[ 0.18890251 -0.03066113 -0.0107627   0.03835532], Reward=1.0
# Step 387: Previous action=0, Observation=[ 0.18828929 -0.2256271  -0.00999559  0.32762317], Reward=1.0
# Step 388: Previous action=0, Observation=[ 0.18377675 -0.42060533 -0.00344313  0.61713725], Reward=1.0
# Step 389: Previous action=1, Observation=[ 0.17536464 -0.22543545  0.00889962  0.32337189], Reward=1.0
# Step 390: Previous action=1, Observation=[ 0.17085593 -0.03044135  0.01536706  0.03350877], Reward=1.0
# Step 391: Previous action=1, Observation=[ 0.1702471   0.1644569   0.01603723 -0.25428635], Reward=1.0
# Step 392: Previous action=1, Observation=[ 0.17353624  0.35934624  0.01095151 -0.54186802], Reward=1.0
# Step 393: Previous action=0, Observation=[ 1.80723165e-01  1.64072090e-01  1.14144771e-04 -2.45754684e-01], Reward=1.0
# Step 394: Previous action=1, Observation=[ 0.18400461  0.35919241 -0.00480095 -0.5384016 ], Reward=1.0
# Step 395: Previous action=0, Observation=[ 0.19118846  0.16413828 -0.01556898 -0.24723526], Reward=1.0
# Step 396: Previous action=0, Observation=[ 0.19447122 -0.03075789 -0.02051369  0.04049648], Reward=1.0
# Step 397: Previous action=0, Observation=[ 0.19385606 -0.22557977 -0.01970376  0.3266372 ], Reward=1.0
# Step 398: Previous action=0, Observation=[ 0.18934447 -0.42041573 -0.01317101  0.61304189], Reward=1.0
# Step 399: Previous action=1, Observation=[ 0.18093615 -0.22511221 -0.00091017  0.31623986], Reward=1.0
# Step 400: Previous action=0, Observation=[ 0.17643391 -0.42022119  0.00541462  0.60863561], Reward=1.0
# Step 401: Previous action=1, Observation=[ 0.16802949 -0.22517535  0.01758733  0.31766303], Reward=1.0
# Step 402: Previous action=1, Observation=[ 0.16352598 -0.03030826  0.0239406   0.030578  ], Reward=1.0
# Step 403: Previous action=1, Observation=[ 0.16291981  0.16446234  0.02455216 -0.2544563 ], Reward=1.0
# Step 404: Previous action=1, Observation=[ 0.16620906  0.35922528  0.01946303 -0.53929506], Reward=1.0
# Step 405: Previous action=0, Observation=[ 0.17339357  0.16383521  0.00867713 -0.24054369], Reward=1.0
# Step 406: Previous action=1, Observation=[ 0.17667027  0.35883214  0.00386625 -0.53047703], Reward=1.0
# Step 407: Previous action=0, Observation=[ 0.18384691  0.16365601 -0.00674329 -0.23657836], Reward=1.0
# Step 408: Previous action=0, Observation=[ 0.18712003 -0.03136895 -0.01147485  0.05396993], Reward=1.0
# Step 409: Previous action=0, Observation=[ 0.18649265 -0.2263245  -0.01039545  0.34301047], Reward=1.0
# Step 410: Previous action=0, Observation=[ 0.18196616 -0.42129703 -0.00353525  0.63239725], Reward=1.0
# Step 411: Previous action=1, Observation=[ 0.17354022 -0.22612594  0.0091127   0.33860308], Reward=1.0
# Step 412: Previous action=1, Observation=[ 0.1690177  -0.03113483  0.01588476  0.04880767], Reward=1.0
# Step 413: Previous action=1, Observation=[ 0.16839501  0.16375578  0.01686091 -0.23882145], Reward=1.0
# Step 414: Previous action=1, Observation=[ 0.17167012  0.35863286  0.01208449 -0.52613864], Reward=1.0
# Step 415: Previous action=0, Observation=[ 0.17884278  0.16334296  0.00156171 -0.22967243], Reward=1.0
# Step 416: Previous action=1, Observation=[ 0.18210964  0.35844256 -0.00303174 -0.52186233], Reward=1.0
# Step 417: Previous action=0, Observation=[ 0.18927849  0.16336341 -0.01346898 -0.23013629], Reward=1.0
# Step 418: Previous action=0, Observation=[ 0.19254576 -0.0315635  -0.01807171  0.05826781], Reward=1.0
# Step 419: Previous action=0, Observation=[ 0.19191449 -0.22642174 -0.01690635  0.34519464], Reward=1.0
# Step 420: Previous action=0, Observation=[ 0.18738605 -0.42129917 -0.01000246  0.63249878], Reward=1.0
# Step 421: Previous action=1, Observation=[ 0.17896007 -0.22603911  0.00264752  0.33668267], Reward=1.0
# Step 422: Previous action=1, Observation=[ 0.17443929 -0.03095493  0.00938117  0.0448358 ], Reward=1.0
# Step 423: Previous action=1, Observation=[ 0.17382019  0.16403125  0.01027789 -0.24487258], Reward=1.0
# Step 424: Previous action=1, Observation=[ 0.17710081  0.35900491  0.00538043 -0.53429597], Reward=1.0
# Step 425: Previous action=0, Observation=[ 0.18428091  0.1638077  -0.00530549 -0.23992257], Reward=1.0
# Step 426: Previous action=0, Observation=[ 0.18755707 -0.03123806 -0.01010394  0.05108215], Reward=1.0
# Step 427: Previous action=0, Observation=[ 0.18693231 -0.22621368 -0.00908229  0.34056015], Reward=1.0
# Step 428: Previous action=0, Observation=[ 0.18240803 -0.42120524 -0.00227109  0.63036526], Reward=1.0
# Step 429: Previous action=1, Observation=[ 0.17398393 -0.22605167  0.01033621  0.33696796], Reward=1.0
# Step 430: Previous action=1, Observation=[ 0.16946289 -0.03107832  0.01707557  0.04756236], Reward=1.0
# Step 431: Previous action=1, Observation=[ 0.16884133  0.16379467  0.01802682 -0.23968454], Reward=1.0
# Step 432: Previous action=1, Observation=[ 0.17211722  0.35865452  0.01323313 -0.52662723], Reward=1.0
# Step 433: Previous action=0, Observation=[ 0.17929031  0.16334889  0.00270059 -0.22980401], Reward=1.0
# Step 434: Previous action=1, Observation=[ 0.18255729  0.35843215 -0.00189549 -0.52163385], Reward=1.0
# Step 435: Previous action=0, Observation=[ 0.18972593  0.16333693 -0.01232817 -0.22954883], Reward=1.0
# Step 436: Previous action=0, Observation=[ 0.19299267 -0.0316067  -0.01691915  0.05922001], Reward=1.0
# Step 437: Previous action=0, Observation=[ 0.19236054 -0.22648203 -0.01573475  0.34651717], Reward=1.0
# Step 438: Previous action=0, Observation=[ 0.1878309  -0.42137667 -0.0088044   0.63419712], Reward=1.0
# Step 439: Previous action=1, Observation=[ 0.17940336 -0.22613302  0.00387954  0.33875453], Reward=1.0
# Step 440: Previous action=1, Observation=[ 0.1748807  -0.03106649  0.01065463  0.04729752], Reward=1.0
# Step 441: Previous action=1, Observation=[ 0.17425937  0.16390108  0.01160058 -0.24200483], Reward=1.0
# Step 442: Previous action=1, Observation=[ 0.17753739  0.35885542  0.00676048 -0.53100617], Reward=1.0
# Step 443: Previous action=0, Observation=[ 0.1847145   0.16363902 -0.00385964 -0.2362007 ], Reward=1.0
# Step 444: Previous action=0, Observation=[ 0.18798728 -0.03142757 -0.00858366  0.05526228], Reward=1.0
# Step 445: Previous action=0, Observation=[ 0.18735873 -0.2264254  -0.00747841  0.34522468], Reward=1.0
# Step 446: Previous action=0, Observation=[ 1.82830224e-01 -4.21440177e-01 -5.73915882e-04  6.35540035e-01], Reward=1.0
# Step 447: Previous action=1, Observation=[ 0.17440142 -0.22631023  0.01213688  0.34267643], Reward=1.0
# Step 448: Previous action=1, Observation=[ 0.16987522 -0.03136303  0.01899041  0.05384532], Reward=1.0
# Step 449: Previous action=1, Observation=[ 0.16924795  0.16348155  0.02006732 -0.232786  ], Reward=1.0
# Step 450: Previous action=1, Observation=[ 0.17251759  0.35831111  0.0154116  -0.51907209], Reward=1.0
# Step 451: Previous action=0, Observation=[ 0.17968381  0.16297561  0.00503016 -0.22157282], Reward=1.0
# Step 452: Previous action=1, Observation=[ 0.18294332  0.3580253   0.0005987  -0.51266479], Reward=1.0
# Step 453: Previous action=0, Observation=[ 0.19010383  0.16289492 -0.00965459 -0.21979326], Reward=1.0
# Step 454: Previous action=0, Observation=[ 0.19336172 -0.0320877  -0.01405046  0.06982864], Reward=1.0
# Step 455: Previous action=0, Observation=[ 0.19271997 -0.22700543 -0.01265389  0.35804567], Reward=1.0
# Step 456: Previous action=0, Observation=[ 0.18817986 -0.42194522 -0.00549297  0.64671181], Reward=1.0
# Step 457: Previous action=1, Observation=[ 0.17974096 -0.22674717  0.00744126  0.35230422], Reward=1.0
# Step 458: Previous action=1, Observation=[ 0.17520601 -0.03173182  0.01448735  0.061977  ], Reward=1.0
# Step 459: Previous action=1, Observation=[ 0.17457138  0.16317945  0.01572689 -0.22610009], Reward=1.0
# Step 460: Previous action=1, Observation=[ 0.17783497  0.35807315  0.01120489 -0.51378097], Reward=1.0
# Step 461: Previous action=0, Observation=[ 0.18499643  0.1627952   0.00092927 -0.21758826], Reward=1.0
# Step 462: Previous action=1, Observation=[ 0.18825233  0.35790386 -0.0034225  -0.50997792], Reward=1.0
# Step 463: Previous action=0, Observation=[ 0.19541041  0.16283029 -0.01362206 -0.21837549], Reward=1.0
# Step 464: Previous action=0, Observation=[ 0.19866702 -0.03209432 -0.01798957  0.06997953], Reward=1.0
# Step 465: Previous action=0, Observation=[ 0.19802513 -0.2269538  -0.01658998  0.35693281], Reward=1.0
# Step 466: Previous action=0, Observation=[ 0.19348605 -0.42183601 -0.00945132  0.64433866], Reward=1.0
# Step 467: Previous action=1, Observation=[ 0.18504933 -0.22658362  0.00343545  0.34869452], Reward=1.0
# Step 468: Previous action=1, Observation=[ 0.18051766 -0.0315107   0.01040934  0.05709689], Reward=1.0
# Step 469: Previous action=1, Observation=[ 0.17988745  0.16346046  0.01155128 -0.23228372], Reward=1.0
# Step 470: Previous action=1, Observation=[ 0.18315666  0.35841547  0.00690561 -0.52130073], Reward=1.0
# Step 471: Previous action=0, Observation=[ 0.19032497  0.163197   -0.00352041 -0.22644977], Reward=1.0
# Step 472: Previous action=0, Observation=[ 0.19358891 -0.03187446 -0.0080494   0.06512062], Reward=1.0
# Step 473: Previous action=0, Observation=[ 0.19295142 -0.22688009 -0.00674699  0.35525308], Reward=1.0
# Step 474: Previous action=0, Observation=[ 1.88413816e-01 -4.21905462e-01  3.58070066e-04  6.45800879e-01], Reward=1.0
# Step 475: Previous action=1, Observation=[ 0.17997571 -0.2267885   0.01327409  0.35323073], Reward=1.0
# Step 476: Previous action=1, Observation=[ 0.17543994 -0.0318578   0.0203387   0.0647629 ], Reward=1.0
# Step 477: Previous action=1, Observation=[ 0.17480278  0.16296674  0.02163396 -0.22143429], Reward=1.0
# Step 478: Previous action=1, Observation=[ 0.17806212  0.35777289  0.01720527 -0.50721525], Reward=1.0
# Step 479: Previous action=0, Observation=[ 0.18521757  0.16241278  0.00706097 -0.20916037], Reward=1.0
# Step 480: Previous action=1, Observation=[ 0.18846583  0.35743306  0.00287776 -0.49960759], Reward=1.0
# Step 481: Previous action=1, Observation=[ 0.19561449  0.55251433 -0.00711439 -0.79138221], Reward=1.0
# Step 482: Previous action=0, Observation=[ 0.20666478  0.35749078 -0.02294203 -0.5009459 ], Reward=1.0
# Step 483: Previous action=0, Observation=[ 0.21381459  0.16269962 -0.03296095 -0.21558042], Reward=1.0
# Step 484: Previous action=0, Observation=[ 0.21706858 -0.03193599 -0.03727256  0.06652566], Reward=1.0
# Step 485: Previous action=0, Observation=[ 0.21642986 -0.22650429 -0.03594205  0.3472198 ], Reward=1.0
# Step 486: Previous action=0, Observation=[ 0.21189978 -0.42109706 -0.02899765  0.62835576], Reward=1.0
# Step 487: Previous action=1, Observation=[ 0.20347784 -0.22558267 -0.01643054  0.32668335], Reward=1.0
# Step 488: Previous action=0, Observation=[ 0.19896618 -0.42046689 -0.00989687  0.61413985], Reward=1.0
# Step 489: Previous action=1, Observation=[ 0.19055685 -0.22520805  0.00238593  0.31835631], Reward=1.0
# Step 490: Previous action=1, Observation=[ 0.18605269 -0.03012016  0.00875305  0.02642677], Reward=1.0
# Step 491: Previous action=1, Observation=[ 0.18545028  0.16487518  0.00928159 -0.26348167], Reward=1.0
# Step 492: Previous action=1, Observation=[ 0.18874779  0.35986342  0.00401196 -0.55322269], Reward=1.0
# Step 493: Previous action=0, Observation=[ 0.19594505  0.16468536 -0.0070525  -0.25927844], Reward=1.0
# Step 494: Previous action=0, Observation=[ 0.19923876 -0.0303352  -0.01223807  0.03117171], Reward=1.0
# Step 495: Previous action=0, Observation=[ 0.19863206 -0.22527953 -0.01161463  0.31996841], Reward=1.0
# Step 496: Previous action=0, Observation=[ 0.19412647 -0.42023417 -0.00521526  0.60896601], Reward=1.0
# Step 497: Previous action=1, Observation=[ 0.18572178 -0.2250397   0.00696406  0.31464501], Reward=1.0
# Step 498: Previous action=1, Observation=[ 0.18122099 -0.03001764  0.01325696  0.02416643], Reward=1.0
# Step 499: Previous action=1, Observation=[ 0.18062064  0.16491171  0.01374028 -0.26430448], Reward=1.0
# Step 500: Previous action=1, Observation=[ 0.18391887  0.35983488  0.0084542  -0.55262211], Reward=1.0
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# 사람은 Observation의 각 원소가 지니는 의미와 물리 법칙을 이용하여 코딩할 수 있지만 기계학습을 사용할 때<br>컴퓨터는 아무런 배경지식 없이 Action에 따라 Observation의 각 원소가 어떻게 변화하는지 학습합니다.
#
# 일반적인 아타리 게임에서는 딥러닝 모델이 그림을 분석하여 현재 상태에서 취할 수 있는 바람직한 액션을 선택합니다.<br>
# 수고하셨습니다.
